# %%
#import requests
# with open('myfile.txt', 'r') as f:
import requests as r

# %%
r
# Out:
# <module 'requests' from 'C:\Users\BIG DATA\Anaconda2\lib\site-packages\requests\__init__.pyc'>

# %%
r.get('http://www.appledaily.com.tw/')
# Out:
# <Response [200]>

# %%
res = r.get('http://www.appledaily.com.tw/')

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# u'<!DOCTYPE html>\n<!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->\n<!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->\n<!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->\n<head>\n  <meta charset="utf-8" />\n  <meta name="description" content="\u53f0\u7063\u860b\u679c\u65e5\u5831\u662f\u53f0\u7063\u5f88\u53d7\u6b61\u8fce\u7684\u65b0\u805e\u7db2\u7ad9\uff0c\u63d0\u4f9b\u860b\u679c\u65e5\u5831\u3001\u5373\u6642\u65b0\u805e\u3001\u52d5\u65b0\u805e\u3001\u5a1b\u6a02\u3001\u9ad4\u80b2\u3001\u793e\u6703\u3001\u751f\u6d3b\u3001\u526f\u520a\u3001\u570b\u969b\u842c\u8c61\u7b49\u7dda\u4e0a\u7248\u5167\u5bb9\uff0c\u5f37\u8abf\u5831\u5c0e\u5f71\u97f3\u5316\u3001\u5716\u50cf\u5316\u3001\u5373\u6642\u5316\u3001\u884c\u52d5\u5316\uff0c\u63d0\u4f9b\u8b80\u8005\u5168\u9762\u4e14\u8c50\u5bcc\u7684\u65b0\u805e\u95b1\u8b80\u611f\u53d7\u3002" />\n  <meta name="keywords" content="\u8
# ...

# %%
with open('apple.html', 'w') as f:
    f.write(res.text.encode('utf-8'))

# %%
# POST
data = {
    "searchMode":"Adv",
    "searchType":"text",
    "querystrA":"黃國昌",
    "select":"AND",
    "source":"",
    "sdate":"2003-05-02",
    "edate":"2016-10-28",
}
res = r.post('http://search.appledaily.com.tw/appledaily/search', data=data)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# u'<!DOCTYPE html>\n<!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->\n<!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->\n<!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->\n<head>\n\t<title>\u641c\u5c0b | \u860b\u679c\u65e5\u5831</title>\n\t<meta charset="utf-8" />\n\t<meta name="description" content="\u53f0\u7063\u860b\u679c\u65e5\u5831\u662f\u53f0\u7063\u5f88\u53d7\u6b61\u8fce\u7684\u65b0\u805e\u7db2\u7ad9\uff0c\u63d0\u4f9b\u860b\u679c\u65e5\u5831\u3001\u5373\u6642\u65b0\u805e\u3001\u52d5\u65b0\u805e\u3001\u5a1b\u6a02\u3001\u9ad4\u80b2\u3001\u793e\u6703\u3001\u751f\u6d3b\u3001\u526f\u520a\u3001\u570b\u969b\u842c\u8c61\u7b49\u7dda\u4e0a\u7248\u5167\u5bb9\uff0c\u5f37\u8abf\u5831\u5c0e\u5f71\u97f3\u5316\u3001\u5716\u50cf\u5316\u3001\u5373\u6642\u5316\u3001\u884c\u52d5\u5316\uff0c\u63d0\u4f9b\u8b80\u8005\u5168\u9762\u4e14\u8c50\u5bcc\u7684\u65b0\u805e\u95b1\u8b80\u
# ...

# %%
with open('mrhuang.txt', 'w') as f:
    f.write(res.text.encode('utf-8'))

# %%
fb = r.get('https://www.facebook.com/')

# %%
fb.headers
# Out:
# {'Strict-Transport-Security': 'max-age=15552000; preload', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Set-Cookie': 'fr=03TSvFbnFMqy4yeyd..BYEsLJ.EZ.AAA.0.0.BYEsLJ.AWVNlIco; expires=Thu, 26-Jan-2017 03:15:21 GMT; Max-Age=7776000; path=/; domain=.facebook.com; httponly', 'public-key-pins-report-only': 'max-age=500; pin-sha256="WoiWRyIOVNa9ihaBciRSC7XHjliYS9VwUGOIud4PB18="; pin-sha256="r/mIkG3eEpVdm+u/ko/cwxzOMo1bk4TyHIlByibiA5E="; pin-sha256="q4PO2G2cbkZhZ82+JgmRUyGMoAeozA+BSXVXQWB8XWQ="; report-uri="http://reports.fb.com/hpkp/"', 'Vary': 'Accept-Encoding', 'X-FB-Debug': 'fJvu5xD2JkjI5chkcxzKv70oYB3jRnnF+Tp1pIxf5s5jLXHXcFEp7RCrpcA6/FGgp5ixish9UhM8/+930fTULw==', 'Connection': 'keep-alive', 'X-XSS-Protection': '0', 'Pragma': 'no-cache', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Date': 'Fri, 28 Oct 2016 03:15:21 GMT', 'P3P': 'CP="Facebook does not have a P3P policy. Learn why here: http://fb.me/p3p"', 'Content-
# ...

# %%
fb.encoding = 'utf-8'

# %%
fb.text
# Out:
# u'<!DOCTYPE html>\n<html lang="zh-Hant" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script>function envFlush(a){function b(c){for(var d in a)c[d]=a[d];}if(window.requireLazy){window.requireLazy([\'Env\'],b);}else{window.Env=window.Env||{};b(window.Env);}}envFlush({"ajaxpipe_token":"AXg5Q31_ceIjYAh8","lhsh":"6AQHLrz5a","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"enableOnRequire":false},"shouldLogCounters":false,"timeslice_categories":{"react_render":true,"reflow":true}});</script><style></style><script>__DEV__=0;CavalryLogger=false;</script><noscript><meta http-equiv="refresh" content="0; URL=/?_fb_noscript=1" /></noscript><title id="pageTitle">\u6b61\u8fce\u4f86\u5230 Facebook \uff
# ...

# %%
with open("fb.txt", 'w') as f:
    f.write(fb.text.encode('utf-8'))

# %%
maple = r.get('http://maplestage.com')

# %%
maple.text
# Out:
# u'\n<!doctype html>\n<html>\n<head>\n<title>\u6953\u6797\u7db2 Maplestage</title>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1230">\n<meta name="description" content="The frontpage of Chinese Art, Culture, and Entertainment">\n<link href=\'https://fonts.googleapis.com/css?family=Roboto:400,300,500\' rel=\'stylesheet\' type=\'text/css\'>\n</head>\n<body>\n<link rel="stylesheet" type="text/css" href="/build/style-bundle-b8ce3e58a7a957ac9f13aa58ab5fafbd.css"/>\n<div id="root"></div>\n<div id="cssload-contain">\n<div class="cssload-wrap" id="cssload-wrap1">\n<div class="cssload-ball" id="cssload-ball1"></div>\n</div>\n<div class="cssload-wrap" id="cssload-wrap2">\n<div class="cssload-ball" id="cssload-ball2"></div>\n</div>\n<div class="cssload-wrap" id="cssload-wrap3">\n<div class="cssload-ball" id="cssload-ball3"></div>\n</div>\n<div class="cssload-wrap" id="cssload-wr
# ...

# %%
with open("maple.txt", 'w') as f:
    f.write(maple.text.encode('utf-8'))

# %%
# Beautifulsoup

# %%
import requests as r
from bs4 import BeautifulSoup

# %%
#res = r.get("http://www.appledaily.com.tw/realtimenews/section/new/")
res = """
<html>
<head>
</head>
<body>
<div class="abdominis rlby clearmen">                       
    <h1 class="dddd"><time>2016 / 10 / 28</time></h1>
    <ul class="rtddd slvl">                                
        <li class="rtddt inter hsv">
            <a href="/realtimenews/article/international/20161028/977110/【環保片】破壞地球　當心「自然之母」懲罰你......" target="_blank">
                <time>13:33</time>
                <h2>國際</h2>
                <h1><font color="#383c40">【環保片】破壞地球　當心 「自然之母」懲...(1202)</font></h1>
            </a>
        </li>
                                                        
    </ul>                            
    <nav class="page_switch lisw fillup" style="margin-top:0em;margin-bottom:1em;text-align:center">
    <span class="clear man"></span>
</div>
</body>
</html>

"""

# %%
# Check if res is OK
res
# Out:
# '\n<html>\n<head>\n</head>\n<body>\n<div class="abdominis rlby clearmen">                       \n    <h1 class="dddd"><time>2016 / 10 / 28</time></h1>\n    <ul class="rtddd slvl">                                \n        <li class="rtddt inter hsv">\n            <a href="/realtimenews/article/international/20161028/977110/\xe3\x80\x90\xe7\x92\xb0\xe4\xbf\x9d\xe7\x89\x87\xe3\x80\x91\xe7\xa0\xb4\xe5\xa3\x9e\xe5\x9c\xb0\xe7\x90\x83\xe3\x80\x80\xe7\x95\xb6\xe5\xbf\x83\xe3\x80\x8c\xe8\x87\xaa\xe7\x84\xb6\xe4\xb9\x8b\xe6\xaf\x8d\xe3\x80\x8d\xe6\x87\xb2\xe7\xbd\xb0\xe4\xbd\xa0......" target="_blank">\n                <time>13:33</time>\n                <h2>\xe5\x9c\x8b\xe9\x9a\x9b</h2>\n                <h1><font color="#383c40">\xe3\x80\x90\xe7\x92\xb0\xe4\xbf\x9d\xe7\x89\x87\xe3\x80\x91\xe7\xa0\xb4\xe5\xa3\x9e\xe5\x9c\xb0\xe7\x90\x83\xe3\x80\x80\xe7\x95\xb6\xe5\xbf\x83 \xe3\x80\x8c\xe8\x87\xaa\xe7\x84\xb6\xe4\xb9\x8b\xe6\xaf\x8d\xe3\x80\x8d\xe6\x87\xb2...(1202)</font></h1>\n            </
# ...

# %%
soup = BeautifulSoup(res, 'lxml') # BeautifulSoup(html, Parser Engine)

# %%
# Let's see what we got
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
article_list = soup.select(".rtddt")

# %%
# Let's see what inside this list
article_list
# Out:
# [<li class="rtddt inter hsv">\n<a href="/realtimenews/article/international/20161028/977110/\u3010\u74b0\u4fdd\u7247\u3011\u7834\u58de\u5730\u7403\u3000\u7576\u5fc3\u300c\u81ea\u7136\u4e4b\u6bcd\u300d\u61f2\u7f70\u4f60......" target="_blank">\n<time>13:33</time>\n<h2>\u570b\u969b</h2>\n<h1><font color="#383c40">\u3010\u74b0\u4fdd\u7247\u3011\u7834\u58de\u5730\u7403\u3000\u7576\u5fc3 \u300c\u81ea\u7136\u4e4b\u6bcd\u300d\u61f2...(1202)</font></h1>\n</a>\n</li>]

# %%
article_dict = {}
for article in article_list:
    article_dict['title'] = article.select('font')[0].text
    article_dict['pub_date'] = article.select('time')[0].text
    article_dict['type'] = article.select('h2')[0].text
    
    print "Title is {}".format(article.select('font')[0].text.encode('utf-8'))
    print "pub_date is {}".format(article.select('time')[0].text)
    print article.select('h2')[0].text
# Out:
# Title is 【環保片】破壞地球　當心 「自然之母」懲...(1202)
# pub_date is 13:33
# 國際

# %%
article_dict
# Out:
# {'pub_date': u'13:33',
#  'title': u'\u3010\u74b0\u4fdd\u7247\u3011\u7834\u58de\u5730\u7403\u3000\u7576\u5fc3 \u300c\u81ea\u7136\u4e4b\u6bcd\u300d\u61f2...(1202)',
#  'type': u'\u570b\u969b'}

# %%
import json
myjson = json.dumps(article_dict, ensure_ascii=False) # This is a unicode string
with open('articles.json', 'w') as f:
    f.write(myjson.encode('utf-8')) # encode our unicode string as 'utf-8' for writing out to file

# %%
# Let's finish the AppleDaily crawler,
import requests as r
from bs4 import BeautifulSoup
res = r.get("http://www.appledaily.com.tw/realtimenews/section/new/")
soup = BeautifulSoup(res.text, 'lxml')
article_list = soup.select('.rtddt')
for article in article_list:
    print "==========article==========="
    print article
# print article_list
# Out:
# ==========article===========
# <li class="rtddt local">
# <a href="/realtimenews/article/local/20161028/977339/純鹼製作毒蒟蒻　知名素食餐廳老闆遭判拘" target="_blank">
# <time>16:42</time>
# <h2>社會</h2>
# <h1><font color="#383c40">純鹼製作毒蒟蒻　知名素食餐廳老闆遭判拘(0)</font></h1>
# </a>
# </li>
# ==========article===========
# <li class="rtddt local even hsv">
# <a href="/realtimenews/article/local/20161028/977287/【有片】走私犀牛角3年賺近億　中藥公會榮譽理事長遭逮" target="_blank">
# <time>16:40</time>
# <h2>社會</h2>
# <h1><font color="#ff0000">【有片】走私犀牛角3年賺近億　中藥公會榮...(28920)</font></h1>
# </a>
# </li>
# ==========article===========
# <li class="rtddt inter">
# <a href="/realtimenews/article/international/20161028/977410/鮑彤談「習核心」：百姓難理解　民主不可能" target="_blank">
# <time>16:40</time>
# <h2>國際</h2>
# <h1><font color="#383c40">鮑彤談「習核心」：百姓難理解　民主不可能(0)</font></h1>
# </a>
# </li>
# ==========article===========
# <li class="rtddt sp_ad even">
# <time>16:40</time>
# <h2>特企</h2>
# <h1>
# ...

# %%
# Let's finish the AppleDaily crawler,
import requests as r
from bs4 import BeautifulSoup

WEBSITE_URL = 'http://www.appledaily.com.tw'

res = r.get(WEBSITE_URL + "/realtimenews/section/new/") # Response Object
soup = BeautifulSoup(res.text, 'lxml') # Beautifulsoup Object
article_list = soup.select('.rtddt') # using Beautifulsoup Object's select() method, this is a list of articles

articles = [] # our result
# how to change page???
# HINT:
# for page in range(.......):
for article in article_list: # for each article in the list.......
    try:
        article_dict = {} # dictionary for EACH ONE of the articles
        article_dict['title'] = article.select_one('font').text # select font element, and it's text attribute
        article_dict['type'] = article.select_one('h2').text # select h2 element, .....
        article_dict['pub_date'] = article.select_one('time').text
        article_url = WEBSITE_URL + article.select_one('a')['href']
        article_dict['article_url'] = article_url
        article_dict['content'] = BeautifulSoup(r.get(article_url).text, 'lxml').select_one('#summary').text
        #print article_dict
        articles.append(article_dict) # push(append) into our result list
        print article_dict
    except Exception as e:
        print e
        
# print article_list
# Out:
# {'content': u'\u6709\u7db2\u53cb\u5728\u300aDcard\u300b\u8cbc\u51fa\u4e00\u5f35\u9632\u6bd2\u8edf\u9ad4\u7684\u5e73\u9762\u5ee3\u544a\uff0c\u4e26\u8868\u793a\u7576\u6642\u548c\u5973\u53cb\u5728\u53f0\u5317\u5e02\u653f\u5e9c\u8f49\u904b\u7ad9\u770b\u5230\u5f8c\uff0c\u5973\u53cb\u8ddf\u4ed6\u8aaa\u9019\u662f\u5728\u8b1b\u4fdd\u96aa\u5957\uff0c\u7b11\u5230\u4e0d\u884c\u7684\u4ed6\u8a62\u554f\u539f\u56e0\uff0c\u7adf\u662f\u300c\u56e0\u70ba\u6709\u5169\u500b\u5973\u751f\u62ff\u8457\u528d\uff0c\u770b\u8d77\u4f86\u5728\u4fdd\u8b77\u4ec0\u9ebc\u300d\uff0c\u7b49\u5973\u53cb\u767c\u73fe\u662f\u9632\u6bd2\u8edf\u9ad4\u5f8c\uff0c\u5979\u81ea\u5df1\u4e5f\u7b11\u7ffb\u4e86\u3002\u53ea\u898b\u9019\u5e73\u9762\u5ee3\u544a\u7684\u6a19\u8a9e\u662f\uff1a\u300c\u96d9\u91cd\u9632\u8b77\uff0c\u4e00\u64ca3\u5230\u4f4d\u300d\uff0c\u4e0b\u65b9\u662f\u300cPC-cillin 2017\u96f2\u7aef\u7248\u300d\u7684\u5b57\u6a23\uff0c\u7136\u5f8c\u67092\u500b\u6a21\u7279\u5152\u4e00\u526f\u897f\u6d0b\u528d\u9078\u624b\u7684\u6
# ...

# %%
import json
myjson = json.dumps(articles, ensure_ascii=False) # This is a unicode string
with open('articles.json', 'w') as f:
    f.write(myjson.encode('utf-8')) # encode our unicode string as 'utf-8' for writing out to file

# %%
# JSON API
import requests as r
nat_url = "http://news.nationalgeographic.com/bin/services/news/public/query/content.json?pageSize=500&offset=100&page=1&contentTypes=news/components/pagetypes/story/article,news/components/pagetypes/story/gallery"
nat_geo = r.get(nat_url)

# %%
len(nat_geo.json())
# Out:
# 500

# %%
nat_geo.json()
# Out:
# [{u'leadMedia': {u'altText': u'Picture of Pluto',
#    u'aspectRatio': 0.69140625,
#    u'height': 1416,
#    u'internal': True,
#    u'isVideo': False,
#    u'url': u'http://news.nationalgeographic.com/content/dam/news/2016/06/20/starstruck0620/01-skywatching-0620.ngsversion.1466451007706.jpg',
#    u'width': 2048},
#   u'page': {u'abstract': u'The red planet will shine high in the southern sky, while distant Pluto will skim near Sagittarius.',
#    u'publishDate': u'Mon Jun 20 15:05:00 EDT 2016',
#    u'series': u'Starstruck',
#    u'sponsorContentLabel': u'Sponsor Content',
#    u'sponsored': False,
#    u'title': u'This Week\u2019s Night Sky: See Stormy Mars and Faint Pluto',
#    u'type': u'story/article',
#    u'url': u'http://news.nationalgeographic.com/2016/06/weeks-night-sky-mars-pluto-solstice-moon-space-astronomy.html'}},
#  {u'leadMedia': {u'altText': u'Picture of bears',
#    u'aspectRatio': 0.66650390625,
#    u'height': 1365,
#    u'internal': True,
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Firefox()
driver.get("http://www.python.org")

elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)



assert "No results found." not in driver.page_source
driver.close()

# %%
import json

# %%
maple = r.post("http://maplestage.com/v1/feed/articles", data=json.dumps({'skip': 0, 'take': 50}), headers={'content-type':'application/json'})

# %%
len(maple.json())
# Out:
# 50

# %%
# NBA.com
nba_qs = {
    'conference':'All',
    'country':'All',
    'individual':'All',
    'locale':'zh_TW',
    'pageIndex':6,
    'position':'All',
    'qualified':'false',
    'season':2016,
    'seasonType':2,
    'split':'All Team',
    'statType':'points',
    'team':'All',
    'total':'perGame'
}
nba = r.get('http://tw.global.nba.com/stats2/league/playerstats.json', params=nba_qs)

# %%
nba.json()
# Out:
# {u'context': {u'device': {u'clazz': None},
#   u'user': {u'countryCode': u'--',
#    u'countryName': u'None',
#    u'locale': u'zh_TW',
#    u'timeZone': u'+08:00',
#    u'timeZoneCity': u'Australia/Perth'}},
#  u'error': {u'detail': None, u'isError': u'false', u'message': None},
#  u'payload': {u'inputParameters': {u'conference': u'All',
#    u'country': u'All',
#    u'division': None,
#    u'individual': u'All',
#    u'maxRecordsPerPage': u'50',
#    u'pageIndex': u'6',
#    u'position': u'All',
#    u'qualified': u'false',
#    u'seasonType': u'2',
#    u'split': u'All Team',
#    u'statType': u'points',
#    u'total': u'perGame'},
#   u'league': {u'id': u'00', u'name': u'NBA'},
#   u'paging': {u'pageIndex': u'6',
#    u'pageSize': u'50',
#    u'totalPages': u'9.0',
#    u'totalRecords': u'450'},
#   u'players': [{u'playerProfile': {u'code': u'malik_beasley',
#      u'country': u'\u7f8e\u570b',
#      u'displayAffiliation': u'Florida State/United States',
# ...
