# %% [markdown]
# # Ian Chen
# ## ianchen06@gmail.com

# %%
# this is a comment

# %%
3
# Out:
# 3

# %%
1 + 1
# Out:
# 2

# %%
8 - 1
# Out:
# 7

# %%
8 / 2
# Out:
# 4

# %%
7 % 3 # 餘數
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
(1+1) * 2
# Out:
# 4

# %% [markdown]
# # Boolean Operations

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and True # &&
# Out:
# True

# %%
True or False # ||
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
1 < 3
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 != 2
# Out:
# True

# %% [markdown]
# # String

# %%
"Hello"
# Out:
# 'Hello'

# %%
"Hello " + "world"
# Out:
# 'Hello world'

# %%
# String Interpolation / String Formatting

# %%
"Hello {}, this is cool".format("ab104")
# Out:
# 'Hello ab104, this is cool'

# %%
"Hello {}, this isssssss cool".format("python")
# Out:
# 'Hello python, this isssssss cool'

# %%
"Hello {}, this {} is awesome".format("python", "ab104")
# Out:
# 'Hello python, this ab104 is awesome'

# %%
"Hello {1}, this {1} is awesome".format("python", "ab104")
# Out:
# 'Hello ab104, this ab104 is awesome'

# %%
"Hello" + "python" + ", this is cool"
# Out:
# 'Hellopython, this is cool'

# %% [markdown]
# # How to get help?

# %%
? dir()

# %%
help(dir())
# Out:
# Help on list object:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __delslice__(...)
#  |      x.__delslice__(i, j) <==> del x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __iadd__(...)
# ...

# %% [markdown]
# # Variables

# %%
#mystr = "awesome stuff"
mystr = "I like Ruby"

# %%
mystr
# Out:
# 'I like Ruby'

# %% [markdown]
# # Control Flow

# %%
if mystr == "awesome stuff":
    print "you are awesome"
else:
    print "How are you?"
# Out:
# How are you?

# %% [markdown]
# # Sequence (string, list)

# %% [markdown]
# ## Common operations for sequence type

# %%
#mystr = 'hello'
mystr = [1,2,3,4,5,6]

# %%
mystr
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mystr[0] # get data using index
# Out:
# 1

# %%
mystr[1]
# Out:
# 2

# %%
mystr[0:2] # 0 <= x < 2
# Out:
# [1, 2]

# %%
mystr[2:]
# Out:
# [3, 4, 5, 6]

# %%
mystr[0:6:2] # mystr[start:end:step]
# Out:
# [1, 3, 5]

# %%
mystr[::2] # mystr[start:end:step]
# Out:
# [1, 3, 5]

# %%
mystr[::-1] # mystr[start:end:step]
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
len(mystr) # Length of sequence
# Out:
# 6

# %%
'h' in mystr
# Out:
# False

# %%
'i' not in mystr
# Out:
# True

# %%
if 'h' in mystr:
    print "found h"

# %% [markdown]
# ## String only methods

# %%
mystr = '    hello-123-apple-pikachu      '

# %%
mystr
# Out:
# '    hello-123-apple-pikachu      '

# %%
mystr.split('123')
# Out:
# ['    hello-', '-apple-pikachu      ']

# %%
mystr = 'hello--123--apple--pikachu'

# %%
mystr.split('--')
# Out:
# ['hello', '123', 'apple', 'pikachu']

# %%
mystr.upper()
# Out:
# 'HELLO--123--APPLE--PIKACHU'

# %%
mystr.strip()
# Out:
# 'hello--123--apple--pikachu'

# %% [markdown]
# ## List only methods

# %%
mylist = [123, 'apple', 123123, 'english']

# %%
mylist
# Out:
# [123, 'apple', 123123, 'english']

# %%
mylist.append('last')

# %%
mylist
# Out:
# [123, 'apple', 123123, 'english', 'last']

# %%
del mylist[0]

# %%
mylist
# Out:
# ['apple', 123123, 'english', 'last']

# %%
mylist.pop()
mylist
# Out:
# ['apple', 123123, 'english']

# %% [markdown]
# # Dictionary

# %%
mydict = {'name': 'Ian',
         'gender': 'male',
         'phone': 112312312,
         'email': 'ianchen06@gmail.com'}

# %%
mydict['name']
# Out:
# 'Ian'

# %%
mydict['phone']
# Out:
# 112312312

# %%
mydict['address'] = 'Taipei'

# %%
mydict
# Out:
# {'address': 'Taipei',
#  'email': 'ianchen06@gmail.com',
#  'gender': 'male',
#  'name': 'Ian',
#  'phone': 112312312}

# %%
mydict.keys()
# Out:
# ['gender', 'email', 'name', 'address', 'phone']

# %%
mydict.values()
# Out:
# ['male', 'ianchen06@gmail.com', 'Ian', 'Taipei', 112312312]

# %% [markdown]
# # Iterable
# ## include all sequence(string, list...etc)  and dict, ..etc

# %%
books = ['harry potter', 'lord of rings', 'japanese 101', 'Master Python in 1 day']

# %%
for book in books:
    print "I have {}".format(book)
# Out:
# I have harry potter
# I have lord of rings
# I have japanese 101
# I have Master Python in 1 day

# %%
namecard = {'name': 'Ian',
         'gender': 'male',
         'phone': 112312312,
         'email': 'ianchen06@gmail.com'}

# %%
for k,v in namecard.items():
    print "key is {}, value is {}".format(k, v)
# Out:
# key is gender, value is male
# key is email, value is ianchen06@gmail.com
# key is name, value is Ian
# key is phone, value is 112312312

# %%
for item in namecard:
    print "item is {}".format(item)
# Out:
# item is gender
# item is email
# item is name
# item is phone

# %%
# Advanced exmaples

# %%
# List comprehension
[book.title() for book in books]
# Out:
# ['Harry Potter', 'Lord Of Rings', 'Japanese 101', 'Master Python In 1 Day']

# %%
res = []
for book in books:
    book_title = book.title()
    res.append(book_title)

# %%
res
# Out:
# ['Harry Potter', 'Lord Of Rings', 'Japanese 101', 'Master Python In 1 Day']

# %%
[book.upper() for book in books if book == 'harry potter']
# Out:
# ['HARRY POTTER']

# %% [markdown]
# # Pythonic way

# %%
books = ['harry potter', 'lord of rings', 'japanese 101', 'Master Python in 1 day']

# %%
is_popular = True

# %%
book_dict = {}

# %% [markdown]
# # File I/O

# %%
mystr = "OK"
with open('myfile.txt', 'w') as f: # r[ead], w[rite], a[ppend], b[inary]
    f.write(mystr + '\n')

# %%
with open('chiporders.tsv', 'r') as f:
    for line in f:
        print line
# Out:
# order_id	quantity	item_name	choice_description	item_price
#
# 1	1	Chips and Fresh Tomato Salsa	NULL	$2.39
#
# 1	1	Izze	[Clementine]	$3.39
#
# 1	1	Nantucket Nectar	[Apple]	$3.39
#
# 1	1	Chips and Tomatillo-Green Chili Salsa	NULL	$2.39
#
# 2	2	Chicken Bowl	[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]	$16.98
#
# 3	1	Chicken Bowl	[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]	$10.98
#
# 3	1	Side of Chips	NULL	$1.69
#
# 4	1	Steak Burrito	[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]	$11.75
#
# 4	1	Steak Soft Tacos	[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]	$9.25
#
# 5	1	Steak Burrito	[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]	$9.25
#
# 5	1	Chips and Guacamole	NULL	$4.45
#
# 6	1	Chicken Crispy Tacos	[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]	$8.75
#
# ...

# %%
# enumerate
books = ['harry potter', 'lord of rings', 'japanese 101', 'Master Python in 1 day']
books
# Out:
# ['harry potter', 'lord of rings', 'japanese 101', 'Master Python in 1 day']

# %%
for index, book in enumerate(books):
    print index
    if index > 1:
        print "nice book"
# Out:
# 0
# 1
# 2
# nice book
# 3
# nice book

# %% [markdown]
# # Functions

# %%
def add(x,y):
    print "x is {}, y is {}".format(x, y)
    return x + y

# %%
add(1,4)
# Out:
# x is 1, y is 4
# 5

# %%
add(5,10)
# Out:
# x is 5, y is 10
# 15

# %%
#add('asdf', 1)
# Out:
# x is asdf, y is 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-49a79831007d> in <module>()
# ----> 1 add('asdf', 1)
#
# <ipython-input-143-4ce2aa9b25ca> in add(x, y)
#       1 def add(x,y):
#       2     print "x is {}, y is {}".format(x, y)
# ----> 3     return x + y
#
# TypeError: cannot concatenate 'str' and 'int' objects

# %%
try:
    f = open('./myfile.txt', 'r')
    add('asdfas', 1)
except TypeError as e:
    print "Your type is not correct"
    print e
finally:
    f.close()
# Out:
# x is asdfas, y is 1
# Your type is not correct
# cannot concatenate 'str' and 'int' objects
